# %%
import seaborn as sns

# %%
mpg_data = sns.load_dataset("mpg")
print(mpg_data)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
print(mpg_data.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Create a visual showing the relationship between horsepower and fuel economy.

# Define the horsepower and miles per gallon by vehicle
mpg = [18.0, 15.0, 27.0, 32.0, 44.0, 17.0, 31.0, 16.0, 28.0]
horsepower = [130.0, 165.0, 86.0, 84.0, 52.0, 140.0, 82.0, 150.0, 79.0]

# Make a scatter plot: mpg on the x-axis, horsepower on the y-axis
plt.scatter(horsepower,mpg)

# Add axis labels
plt.xlabel('Horsepower')
plt.ylabel('Fuel Economy (mpg)')

# Add title
plt.title('Horsepower vs. Fuel Economy')

plt.show()

# There is a moderate negative correlatation between Horsepower and fuel economy (MPG). Generally, increased horsepower in a vehicle 
# does not increase its miles per gallon (MPG) because more power usually requires more fuel.

# %%
#Create a table summarizing fuel economy by country of origin.

# Explore and clean the data (if needed)
mpg_data = mpg_data.dropna()

# Summarize data
summary_df = df.groupby('Origin')['MPG'].mean().reset_index()

# Create a bar chart using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Origin', y='MPG', data=summary_df, palette='viridis')

# Adjust plot aesthetics
plt.title('Average Fuel Economy by Country of Origin')
plt.xlabel('Country of Origin')
plt.ylabel('Fuel Economy (mpg)')

# Show the plot
plt.show()

#Fuel economy by country of origin puts Europe in the lead with the highest average miles per gallon.

# %%
print(mpg_data[['model_year','mpg']].head())
# Out:
#    model_year   mpg
# 0          70  18.0
# 1          70  15.0
# 2          70  18.0
# 3          70  16.0
# 4          70  17.0

# %%
#Create a visual showing how fuel economy has changed over time.

# Make a line plot: model year on the x-axis, mpg on the y-axis
plt.figure(figsize=(12, 6))
sns.lineplot(x='model_year', y='mpg', data=mpg_data, marker='o', color='blue', label='Fuel Economy')

plt.title('Fuel Economy Over Time')
plt.xlabel('Model Year')
plt.ylabel('Average Fuel Economy (mpg)')

plt.legend()
plt.grid(True)
plt.show()

#Fuel economy has improved over time, most notably from 1976-1980.

# %%
# Explore and clean the data (if needed)
mpg_data = mpg_data.dropna()

# Create a bar chart using Seaborn
plt.figure(figsize=(12, 6))
sns.scatterplot(x='weight', y='mpg', data=mpg_data)

# Adjust plot aesthetics
plt.title('Weight of Vehicle vs. Fuel Economy')
plt.xlabel('Weight of Vehicle')
plt.ylabel('Fuel Economy (mpg)')

plt.show()

#There is a negative correlatation between weight of vehicle and fuel efficiency (MPG).

# %%
# Explore and clean the data (if needed)
mpg_data = mpg_data.dropna()

# Create a bar chart using Seaborn
plt.figure(figsize=(12, 6))
sns.scatterplot(x='acceleration', y='mpg', data=mpg_data)

# Adjust plot aesthetics
plt.title('Acceleration vs. Fuel Economy')
plt.xlabel('Acceleration')
plt.ylabel('Fuel Economy (mpg)')

plt.show()

#There is a moderate positive correlatation between weight of vehicle and fuel efficiency (MPG).
